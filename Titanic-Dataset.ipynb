# %%
import pandas as pd
df=pd.read_csv('train.csv')
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
survived_count = (df['Survived'] == 1).sum()
died_count = (df['Survived'] == 0).sum()
print("Total persons survived =",survived_count)
print("Total persons died =",died_count)
# Out:
# Total persons survived = 342
# Total persons died = 549

# %%
colours=["darkgreen","firebrick"]
data={
    'Survived': survived_count,
    'Died': died_count
}
plt.bar(data.keys(),data.values(),color=colours,width=0.2)
plt.xlabel("Survival status")
plt.ylabel("Total persons")
plt.show()

# %%
male_count=(df['Sex']=='male').sum()
female_count=(df['Sex']=='female').sum()
print("Total number of males =",male_count)
print("Total number of females =",female_count)
# Out:
# Total number of males = 577
# Total number of females = 314

# %%
colours=["sandybrown","sienna"]
data={'Males':male_count,'Females':female_count}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title("Gender distribution")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
males_survived=((df['Survived']==1) & (df['Sex']=='male')).sum()
females_survived=((df['Survived']==1) & (df['Sex']=='female')).sum()
print("Total number of males survived =",males_survived)
print("Total number of females survived =",females_survived)
# Out:
# Total number of males survived = 109
# Total number of females survived = 233

# %%
males_died = male_count - males_survived
colours=["sandybrown","sienna"]
data={"Males Died":males_died,"Males Survived":males_survived

}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title("Survival status of Males")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
females_died = female_count - females_survived
colours=["sandybrown","sienna"]
data={"Females Died":females_died,"Females Survived":females_survived

}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title("Survival status of Females")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
colours=["sandybrown","sienna"]
data={"Females Survived":females_survived,"Males Survived":males_survived
}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title("Females Survived vs Males Survived")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
colours=["sandybrown","sienna"]
data={"Males Died":males_died ,"Females Died":females_died ,"Males Survived":males_survived  ,"Females Survived":females_survived
}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title("Survival Status by Gender")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
null_age=df['Age'].isnull().sum()
print(null_age)
# Out:
# 177

# %%
mean_age_miss = df[(df['Sex'] == 'female') & (df['Name'].str.contains('Miss'))]['Age'].mean()
mean_age_mrs = df[(df['Sex'] == 'female') & (df['Name'].str.contains('Mrs'))]['Age'].mean()
df.loc[(df['Age'].isnull()) & (df['Sex'] == 'female') & (df['Name'].str.contains('Miss')), 'Age'] = mean_age_miss
df.loc[df['Age'].isnull() & (df['Sex']=='female') & (df['Name'].str.contains('Mrs')),'Age']=mean_age_mrs
missing=df['Age'].isnull().sum()
print(missing)
# Out:
# 124

# %%
Class1=df[(df['Sex']=='male') & (df['Pclass']==1)]['Age'].mean()
Class2=df[(df['Sex']=='male') & (df['Pclass']==2)]['Age'].mean()
Class3=df[(df['Sex']=='male') & (df['Pclass']==3)]['Age'].mean()
df.loc[(df['Age'].isnull()) & (df['Sex']=='male') & (df['Pclass']==1),'Age']=Class1
df.loc[(df['Age'].isnull()) & (df['Sex']=='male') & (df['Pclass']==2),'Age']=Class2
df.loc[(df['Age'].isnull()) & (df['Sex']=='male') & (df['Pclass']==3),'Age']=Class3
missing=df['Age'].isnull().sum()
print(missing)
# Out:
# 0

# %%
class1_count=(df['Pclass']==1).sum()
class2_count=(df['Pclass']==2).sum()
class3_count=(df['Pclass']==3).sum()
print("Total passengers in Class 1 :",class1_count)
print("Total passengers in Class 2 :",class2_count)
print("Total passengers in Class 2 :",class3_count)
# Out:
# Total passengers in Class 1 : 216
# Total passengers in Class 2 : 184
# Total passengers in Class 2 : 491

# %%
class1_survival=((df['Pclass']==1) & (df['Survived']==1)).sum()
class2_survival=((df['Pclass']==2) & (df['Survived']==1)).sum()
class3_survival=((df['Pclass']==3) & (df['Survived']==1)).sum()
print("No. of Survivors from Class 1 :",class1_survival)
print("No. of Survivors from Class 2 :",class2_survival)
print("No. of Survivors from Class 3 :",class3_survival)
# Out:
# No. of Survivors from Class 1 : 136
# No. of Survivors from Class 2 : 87
# No. of Survivors from Class 3 : 119

# %%
class1_died=class1_count-class1_survival

colours=["sandybrown","bisque"]
data={'Survived':class1_survival, 'Died':class1_died}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title('Survival Rate of Class 1')
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
class2_died=class2_count-class2_survival

colours=["sandybrown","bisque"]
data={'Survived':class2_survival, 'Died':class2_died}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title('Survival Rate of Class 2')
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
class3_died=class3_count-class3_survival

colours=["sandybrown","bisque"]
data={'Survived':class3_survival, 'Died':class3_died}
plt.pie(data.values(),labels=data.keys(),shadow=True,colors=colours,autopct='%2.1f%%')
plt.title('Survival Rate of Class 3')
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
infants_count=(df['Age']<=1).sum()
print("Total no. of Infants :",infants_count)

children_count=((df['Age']>1) & (df['Age']<=12)).sum()
print("Total no. of Children :",children_count)

teens_count=((df['Age']>=13) & (df['Age']<=19)).sum()
print("Total no. of Teens :",teens_count)

young_adult_count=((df['Age']>=20) & (df['Age']<=39)).sum()
print("Total no. of Young adults :",young_adult_count)

middle_aged_count=((df['Age']>=40) & (df['Age']<=59)).sum()
print("Total no. of Middle aged persons :",middle_aged_count)

seniors_count=(df['Age']>=60).sum()
print("Total no. of Senior citizens :",seniors_count)
# Out:
# Total no. of Infants : 14
# Total no. of Children : 55
# Total no. of Teens : 95
# Total no. of Young adults : 543
# Total no. of Middle aged persons : 158
# Total no. of Senior citizens : 26

# %%
infants_survived=((df['Age']<=1) & (df['Survived']==1)).sum()
print("No. of Infants survived :",infants_survived)

children_survived=((df['Age']>1) & (df['Age']<=12) & (df['Survived']==1)).sum()
print("No. of Children survived :",children_survived)

teens_survived=((df['Age']>=13) & (df['Age']<=19) & (df['Survived']==1)).sum()
print("No. of Teens survived :",teens_survived)

young_adults_survived=((df['Age']>=20) & (df['Age']<=39) & (df['Survived']==1)).sum()
print("No. of Young adults survived :",young_adults_survived)

middle_aged_survived=((df['Age']>=40) & (df['Age']<=59) & (df['Survived']==1)).sum()
print("No. of Middle aged persons survived :",middle_aged_survived)

seniors_survived=((df['Age']>=60) & (df['Survived']==1)).sum()
print("No. of Seniors survived :",seniors_survived)
# Out:
# No. of Infants survived : 12
# No. of Children survived : 28
# No. of Teens survived : 39
# No. of Young adults survived : 197
# No. of Middle aged persons survived : 59
# No. of Seniors survived : 7

# %%
Total=(infants_count,children_count,teens_count,young_adult_count,middle_aged_count,seniors_count)
Survived=(infants_survived,children_survived,teens_survived,young_adults_survived,middle_aged_survived,seniors_survived)
x=['Infants','Children','Teens','Young Adults','Middle Aged','Seniors']
xpos=np.arange(len(x))
plt.figure(figsize=(10,7))
barwidth=0.4
plt.bar(xpos,Total,color="sienna",width=barwidth,label='Total')
plt.bar(xpos+0.4,Survived,color="sandybrown",width=barwidth,label='Survived')
plt.grid()
plt.legend()
plt.xticks(xpos+0.2,x)
plt.show()

# %%
null_value=df['Embarked'].isnull().sum()
print(null_value)
# Out:
# 2

# %%
total_ports=df['Embarked'].unique()
print(total_ports)
print(len(total_ports))
# Out:
# ['S' 'C' 'Q' nan]
# 4

# %%
df_cleaned=df.dropna(subset=['Embarked'],inplace=True)

# %%
null_value=df['Embarked'].isnull().sum()
print(null_value)
# Out:
# 0

# %%
total_ports=df['Embarked'].unique()
print(total_ports)
print(len(total_ports))
# Out:
# ['S' 'C' 'Q']
# 3

# %%
total_s_port=(df['Embarked']=='S').sum()
total_c_port=(df['Embarked']=='C').sum()
total_q_port=(df['Embarked']=='Q').sum()
print('Total passengers embarked from port S :',total_s_port)
print('Total passengers embarked from port C :',total_c_port)
print('Total passengers embarked from port Q :',total_q_port)
# Out:
# Total passengers embarked from port S : 644
# Total passengers embarked from port C : 168
# Total passengers embarked from port Q : 77

# %%
s_port_survival=((df['Embarked']=='S') & (df['Survived']==1)).sum()
c_port_survival=((df['Embarked']=='C') & (df['Survived']==1)).sum()
q_port_survival=((df['Embarked']=='Q') & (df['Survived']==1)).sum()
print("Total survivors from port 'S' :",s_port_survival)
print("Total survivors from port 'C' :",c_port_survival)
print("Total survivors from port 'Q' :",q_port_survival)
# Out:
# Total survivors from port 'S' : 217
# Total survivors from port 'C' : 93
# Total survivors from port 'Q' : 30

# %%
Total=(total_s_port,total_c_port,total_q_port)
Survived=(s_port_survival,c_port_survival,q_port_survival)
x=['S-port','C-port','Q-port']
xpos=np.arange(len(x))
plt.figure(figsize=(10,7))
barwidth=0.2
plt.bar(xpos,Total,color="sienna",width=barwidth,label='Total')
plt.bar(xpos+0.2,Survived,color="sandybrown",width=barwidth,label='Survived')
plt.grid()
plt.legend()
plt.xticks(xpos+0.1,x)
plt.show()

# %%
class1_s_port=((df['Embarked']=='S') & (df['Pclass']==1)).sum()
class2_s_port=((df['Embarked']=='S') & (df['Pclass']==2)).sum()
class3_s_port=((df['Embarked']=='S') & (df['Pclass']==3)).sum()
print('Class 1 passengers embarked from port S :',class1_s_port)
print('Class 2 passengers embarked from port S :',class2_s_port)
print('Class 3 passengers embarked from port S :',class3_s_port)
# Out:
# Class 1 passengers embarked from port S : 127
# Class 2 passengers embarked from port S : 164
# Class 3 passengers embarked from port S : 353

# %%
colours=["sienna","bisque","sandybrown"]
data={'Class 1':class1_s_port,'Class 2':class2_s_port,'Class 3':class3_s_port}
plt.pie(data.values(),labels=data.keys(),colors=colours,shadow=True,autopct='%2.1f%%')
plt.title("Passenger Class Distribution on port S")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
class1_c_port=((df['Embarked']=='C') & (df['Pclass']==1)).sum()
class2_c_port=((df['Embarked']=='C') & (df['Pclass']==2)).sum()
class3_c_port=((df['Embarked']=='C') & (df['Pclass']==3)).sum()
print('Class 1 passengers embarked from port C :',class1_c_port)
print('Class 2 passengers embarked from port C :',class2_c_port)
print('Class 3 passengers embarked from port C :',class3_c_port)
# Out:
# Class 1 passengers embarked from port C : 85
# Class 2 passengers embarked from port C : 17
# Class 3 passengers embarked from port C : 66

# %%
colours=["sienna","bisque","sandybrown"]
data={'Class 1':class1_c_port,'Class 2':class2_c_port,'Class 3':class3_c_port}
plt.pie(data.values(),labels=data.keys(),colors=colours,shadow=True,autopct='%2.1f%%')
plt.title("Passenger Class Distribution on port C")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
class1_q_port=((df['Embarked']=='Q') & (df['Pclass']==1)).sum()
class2_q_port=((df['Embarked']=='Q') & (df['Pclass']==2)).sum()
class3_q_port=((df['Embarked']=='Q') & (df['Pclass']==3)).sum()
print('Class 1 passengers embarked from port Q :',class1_q_port)
print('Class 2 passengers embarked from port Q :',class2_q_port)
print('Class 3 passengers embarked from port Q :',class3_q_port)
# Out:
# Class 1 passengers embarked from port Q : 2
# Class 2 passengers embarked from port Q : 3
# Class 3 passengers embarked from port Q : 72

# %%
colours=["sienna","bisque","sandybrown"]
data={'Class 1':class1_q_port,'Class 2':class2_q_port,'Class 3':class3_q_port}
plt.pie(data.values(),labels=data.keys(),colors=colours,shadow=True,autopct='%2.1f%%')
plt.title("Passenger Class Distribution on port Q")
plt.legend(loc="center left",bbox_to_anchor=(1.2,0.7),labels=data.keys())
plt.show()

# %%
family=df['Parch'].unique()
print(family)
print(len(family))
# Out:
# [0 1 2 5 3 4 6]
# 7

# %%
family2=df['SibSp'].unique()
print(family2)
print(len(family2))
# Out:
# [1 0 3 4 2 5 8]
# 7

# %%
pd.crosstab(df['SibSp'],df['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f01e1_row0_col0 {
#   background-color: #47a366;
#   color: #f1f1f1;
# }
# #T_f01e1_row0_col1 {
#   background-color: #63b166;
#   color: #f1f1f1;
# }
# #T_f01e1_row0_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_f01e1_row1_col0 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_f01e1_row1_col1 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_f01e1_row1_col2 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_f01e1_row2_col0, #T_f01e1_row4_col0 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_f01e1_row2_col1 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_f01e1_row2_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_f01e1_row3_col0, #T_f01e1_row3_col1, #T_f01e1_row3_col2, #T_f01e1_row4_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_f01e1_row4_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# ...

# %%
pd.crosstab(df['Parch'],df['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_87b15_row0_col0 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_87b15_row0_col1 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_87b15_row0_col2 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_87b15_row1_col0 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_87b15_row1_col1 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_87b15_row1_col2 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_87b15_row2_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_87b15_row2_col1 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_87b15_row2_col2 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_87b15_row3_col0, #T_87b15_row4_col1, #T_87b15_row4_col2, #T_87b15_row5_col1, #T_87b15_row6_col0, #T_87b15_row6_col1, #T_87b15_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_87b15_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# ...
